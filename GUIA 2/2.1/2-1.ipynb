# %%
# Import libs
import sys
import matplotlib.pyplot as plt
from docplex.mp.model import Model
from docplex.mp.relax_linear import LinearRelaxer

try:
    import docplex.mp
except:
    raise Exception('Please install docplex. See https://pypi.org/project/docplex/')

# %%
# Declare the parameters

# name, benefit, max demand, min demand
products = [("A", 18),
            ("B1", 15),
            ("B2", 15),
            ("C", 18),]

# week resources are a list of simple tuples (name, capacity)
# each machine works 2 shifts of 8 hours, from Monday to Friday 
# productive capacity per week => 2*8*5 = 80
resources = [("Maquina1", 80),
             ("Maquina2", 80),
             ("LanaNormal", 36),
             ("LanaMejorada", 20)]

consumptions = {("A", "Maquina1"): 5,
                ("B1", "Maquina1"): 6,
                ("B2", "Maquina1"): 0,
                ("C", "Maquina1"): 0,
                ("A", "Maquina2"): 0,
                ("B1", "Maquina2"): 0,
                ("B2", "Maquina2"): 4,
                ("C", "Maquina2"): 4,
                ("A", "LanaNormal"): 0,
                ("B1", "LanaNormal"): 1.8,
                ("B2", "LanaNormal"): 1.8,
                ("C", "LanaNormal"): 0,
                ("A", "LanaMejorada"): 1.6,
                ("B1", "LanaMejorada"): 0,
                ("B2", "LanaMejorada"): 0,
                ("C", "LanaMejorada"): 1.2}

# %%
# Declare the parameters

# name, benefit, max demand, min demand
products = [("A", 18),
            ("B1", 15),
            ("B2", 15),
            ("C", 18),]

# week resources are a list of simple tuples (name, capacity)
# each machine works 2 shifts of 8 hours, from Monday to Friday 
# productive capacity per week => 2*8*5 = 80
resources = [("Maquina1", 80),
             ("Maquina2", 80),
             ("LanaNormal", 36),
             ("LanaMejorada", 20)]

consumptions = {("A", "Maquina1"): 5,
                ("B1", "Maquina1"): 6,
                ("B2", "Maquina1"): 0,
                ("C", "Maquina1"): 0,
                ("A", "Maquina2"): 0,
                ("B1", "Maquina2"): 0,
                ("B2", "Maquina2"): 4,
                ("C", "Maquina2"): 4,
                ("A", "LanaNormal"): 0,
                ("B1", "LanaNormal"): 1.8,
                ("B2", "LanaNormal"): 1.8,
                ("C", "LanaNormal"): 0,
                ("A", "LanaMejorada"): 1.6,
                ("B1", "LanaMejorada"): 0,
                ("B2", "LanaMejorada"): 0,
                ("C", "LanaMejorada"): 1.2}
# Create the model with constraints and objective
def create_model():
    mdl = Model(name="Ejercicio 2.1")

    produccion_vars = mdl.continuous_var_dict(products, name='produccion')

    # --- constraints ---

    # --- resources disp equipo ---
    # Suma todas las restricciones del mismo tipo
    mdl.add_constraints((mdl.sum(produccion_vars[p] * consumptions[p[0], res[0]] for p in products) <= res[1], 'Disp_%s' % res[0]) for res in resources)

    # --- print information ---
    mdl.print_information()

    mdl.add_constraints( (produccion_vars[products[1]] + produccion_vars[products[2]] ) >= 10,)
    
    # --- set the objective ---
    total_benefit = mdl.sum(produccion_vars[p] * p[1] for p in products)
    mdl.maximize(total_benefit)

    return mdl, produccion_vars, products

# Solve the model
def solve_model(mdl):
    solution = mdl.solve()

    if not solution:
        print("Model cannot be solved.")
        sys.exit(1)

    obj = mdl.objective_value

    print("* Production model solved with objective: {:g}".format(obj))
    print("* Total benefit=%g" % mdl.objective_value)
    for p in products:
        print("Production of {product}: {prod_var:.3f}".format(product=p[0], prod_var=produccion_vars[p].solution_value))

# Create the model with constraints and objective
mdl, produccion_vars, products = create_model()

# Solve the model
solve_model(mdl)
# Out:
# Model: Ejercicio 2.1
#  - number of variables: 4
#    - binary=0, integer=0, continuous=4
#  - number of constraints: 4
#    - linear=4
#  - parameters: defaults
#  - objective: none
#  - problem type is: LP
# ---------------------------------------------------------------------------
# DOcplexException                          Traceback (most recent call last)
# Cell In[3], line 72
#      69         print("Production of {product}: {prod_var:.3f}".format(product=p[0], prod_var=produccion_vars[p].solution_value))
#      71 # Create the model with constraints and objective
# ---> 72 mdl, produccion_vars, products = create_model()
#      74 # Solve the model
#      75 solve_model(mdl)
#
# Cell In[3], line 48, in create_model()
#      45 # --- print information ---
#      46 mdl.print_information()
# ---> 48 mdl.add_constraints( (produccion_vars[products[1]] + produccion_vars[products[2]] ) >= 10,)
#      50 # --- set the objective ---
#      51 total_benefit = mdl.sum(produccion_vars[p] * p[1] for p in products)
#
# File c:\Users\San\Desktop\FIUBA-modelos-y-optimizacion-tpg\mo-env\lib\site-packages\docplex\mp\model.py:4184, in Model.add_constraints(self, cts, names)
#    4155 def add_constraints(self, cts, names=None):
#    4156     """ Adds a batch of linear constraints to the model in one operation.
#    4157
#    4158     Each constraint from the `cts` iterable is added to the model.
#    (...)
#    4182
#    4183     """
# -> 4184     self._checker.typecheck_iterable(cts)
#    4185     if names is not None and not self.ignore_names:
#    4186         if not is_iterable(names) or (is_string(names) and not names):
#
# File c:\Users\San\Desktop\FIUBA-modelos-y-optimizacion-tpg\mo-env\lib\site-packages\docplex\mp\tck.py:280, in StandardTypeChecker.typecheck_iterable(self, arg)
#     277 def typecheck_iterable(self, arg):
#     278     # INTERNAL: checks for an iterable
#     279     if not is_iterable(arg):
# --> 280         self.fatal("Expecting iterable, got: {0!s}", arg)
#
# File c:\Users\San\Desktop\FIUBA-modelos-y-optimizacion-tpg\mo-env\lib\site-packages\docplex\mp\tck.py:256, in DOcplexLoggerTypeChecker.fatal(self, msg, *args)
#     255 def fatal(self, msg, *args):
# --> 256     self._logger.fatal(msg, args)
#
# File c:\Users\San\Desktop\FIUBA-modelos-y-optimizacion-tpg\mo-env\lib\site-packages\docplex\mp\error_handler.py:210, in AbstractErrorHandler.fatal(self, msg, args)
#     208 resolved_message = resolve_pattern(msg, args)
#     209 docplex_error_stop_here()
# --> 210 raise DOcplexException(resolved_message)
#
# DOcplexException: Expecting iterable, got: produccion_B1_15+produccion_B2_15 >= 10
